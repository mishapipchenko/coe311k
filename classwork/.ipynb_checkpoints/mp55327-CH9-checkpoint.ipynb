# %%
import numpy as np
import matplotlib.pyplot as plt

# Data points 

X = np.array([1, 2, 3, 4, 5])

Y = np.array([1.2, 2.8, 3.6, 4.5, 5.1])

# Stack the design matrix with a column of ones (for the intercept)

A = np.vstack([X, np.ones(len(X))]).T

# Solve using least squares

m, c = np.linalg.lstsq(A, Y, rcond=None)[0]


plt.figure()
plt.scatter(X,Y)
plt.plot(X, m*X + c)
plt.title("data points and best fit line")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

print(f"Slope: {m}, Intercept: {c}")
# Out:
# Slope: 0.9500000000000001, Intercept: 0.5900000000000001

# %% [markdown]
# least squares approximation looks good

# %%
X = np.sort(np.random.rand(5) * 10)
Y = np.random.rand(5) * 10
A = np.vstack([X, np.ones(len(X))]).T

m, c = np.linalg.lstsq(A, Y, rcond=None)[0]

plt.figure()
plt.scatter(X,Y)
plt.plot(X, m*X + c)
plt.title("data points and best fit line")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

print(f"Slope: {m}, Intercept: {c}")
# Out:
# Slope: -0.18704094012400976, Intercept: 6.495245995717389

# %% [markdown]
# As only X is sorted, least squares struggles due to Y being randomized. A good linear approximation is not possible with such random y points, and therefore the line is not a good fit for the points.

# %%
m = 2
b = 5

x = np.arange(0,1.01, 0.01)

error = np.random.uniform(-1,1, size=len(x))
y = m*x + b + error
y

A = np.vstack([x, np.ones(len(x))]).T
m_f, b_f = np.linalg.lstsq(A, y, rcond=None)[0]
print(m_f, b_f)

y_pred = m_f*x + b_f
res = y - y_pred

print(res)

rmax = np.argmax(res)
rmin = np.argmin(res)

print(f"Max residual point -> x: {x[rmax]}, y: {y[rmax]}, residual: {res[rmax]}")
print(f"Min residual point -> x: {x[rmin]}, y: {y[rmin]}, residual: {res[rmin]}")

plt.scatter(x, y)
plt.plot(x, y_pred, color='red')
plt.scatter(x[rmax], y[rmax])
plt.scatter(x[rmin], y[rmin])
plt.title("data points and best fit line")
plt.xlabel("x")
plt.ylabel("y")
plt.show()
# Out:
# 2.076588736506535 5.05396589591478
# [-0.60022062 -1.03456782  0.20330915  0.54652968  0.08133128  0.56072919
#   0.04208917  0.21334687  0.03493969 -0.90793442 -0.52700578 -0.29789659
#   0.4207933   0.82028509  0.34344423 -0.61189921  0.10211731 -0.12399802
#   0.57727689  0.36879755 -0.30045557  0.29313163  0.213813   -0.97343544
#   0.58056454  0.45256274  0.2996357   0.37138582 -0.90931569 -0.46808295
#  -0.50221682  0.23734054 -0.56265894 -0.59308318  0.46251101  0.86522441
#  -0.31611909 -0.046352   -0.35892952 -0.04521026  0.83834972 -0.20592003
#  -0.43255103 -0.4236143   0.61422138  0.17143673 -0.54339447  0.83380122
#  -0.16082995  0.57032539 -0.67060872  0.81466256  0.35649374 -0.95458825
#  -0.91060561  0.47164922 -0.91643914  0.84797484  0.61583143 -0.47973407
#   0.35005446  0.39753029  0.26942037  0.25680839  0.84339781  0.22736344
#   0.39469222  0.03342077 -0.82541729  0.88506799  0.58248083 -0.01836192
#  -0.07399797  0.71136801 -0.83436058  0.53405934 -1.09911175 -0.52463692
#  -0.99232993  0.32516405 -0.10787905  0.7648575   0.35444665 -0.70240638
#  -0.43263119 -0.45459553  0.21625817  0.05426861 -0.93611008  0.39344907
#  -0.82661177 -0.31939174 -0.36835335  0.79357958 -0.37337609  0.54645932
#  -0.31764729  0.37500157 -0.29367282  0.10685548  0.73665019]
# Max residual point -> x: 0.6900000000000001, y: 7.37188011523024, residual: 0.8850679911259496
# Min residual point -> x: 0.76, y: 5.533061589328061, residual: -1.099111746331686

# %% [markdown]
# The least squares method well approximates the original function, as can be seen by the asymptote of 5 and the line ending at 7. The residuals of 0.885 and -1.1 are also very close to the noise, so that makes sense.
